# %%
# Text Variables
Name = 'NAMİG ALASGAROV'
Title = 'Data Analyst'
Contact = 'Baku, Azerbaijan\n50-877-66-57\nnamig.alasgarov@outlook.com\nwww.linkedin.com/in/namigalasgarov\nhttps://github.com/NamigAlasgarov'
ExpHeader = 'EXPERIENCE'
ExpOneTitle = 'Accountant at GroupOne LLC (Paul Azerbaijan)'
ExpOneDesc = '- Working in electronic portals (e-gov, e-sosial, e-taxes, etc.),\n- Preparation of daily and monthly reports\n- Preparation and payment of salary schedules, submission of SSPF reports'
ExpTwoTitle = 'Internship at State Oil Company of Azerbaijan Republic (SOCAR)'
ExpTwoDesc = '- I have worked as trainee at this company around six months and my research\n topic was different aspects of leasing in Azerbaijan and especially in SOCAR.'
ExpThreeTitle = 'Trainee - Business Development Management at Efektas Group'
ExpThreeDesc = 'I have worked for Efektas Group half a year as a trainee.\nMy primary roles were to identify new business partners for collaborations\n- evaluate existing businesses to drive additional value\n- assist with deals and partners negotiations'
EduHeader = 'EDUCATION'
EduOneTitle = 'Master’s Degree, Economics and Finance at Ca Foscari University\nof Venice'
EduOneTime = '2018 – 2021 Venice, Italy'
EduTwoTitle = 'Master’s Degree, Erasmus+ Exchange Programme at Vytauto\nDidžiojo Universitetas'
EduTwoTime = '2021 – 2021 Kaunas, Lithuania'
EduThreeTitle = 'Bachelor’s Degree, Industrial Management at Azerbaijan State\nUniversity of Oil and Industry'
EduThreeTime = '2014 – 2018 Baku, Azerbaijan'
CoursesHeader = 'COURSES & CERTIFICATIONS'
CourseOneTitle = 'Financial Markets Course at Yale University'
CourseOneTime = 'November 2020 – No expiration date'
CourseTwoTitle = 'BMC’s Core Concepts and Portfolio Management'
CourseTwoTime = 'April 2020 – No expiration date'
CourseThreeTitle = 'Innab Business School – Data Analytics'
CourseThreeTime = 'January 2022 – May 2022'
CourseThreeDesc = 'Excel ✓ SQL ✓ Statistics ✓ Power BI ✓ Python ✓ '
ProjectHeader = 'PROJECTS'
ProjectOneTitle = 'Author of Idea, Organiser at\nProfessional Management Form'
ProjectOneTime = 'Decembre 2017'
ProjectOneDesc = 'www.asoiu.edu.az/en/news/368-adnsu-da-pesekar-idareetme-forumu-kecirilib'
ProjectTwoTime = '2013-2017'
SkillsHeader = 'Skills'
SkillsDesc = '- Ms Word & Ms PowerPoint\n- Excel\n- Pivot Tables\n- Power Query&PowerPivot&DAX\n- Power BI\n- Data Visualisation\n- Power Automate\n- R Studio\n- Oracle SQL\n- GitHub\n- Python'
LanguageTitle = 'LANGUAGES'
LanguageDesc = '- Azerbaijani \n- English\n- Italian\n- Turkish'
##CodeTitle = 'View Portfolio'
# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline
# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 11))
# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
# set background color
ax.set_facecolor('white')
# remove axes
plt.axis('off')
# add text
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=14)
plt.annotate(Contact, (.7,.906), weight='regular', fontsize=8, color='#ffffff')
plt.annotate(ExpHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(ExpOneTitle, (.02,.832), weight='bold', fontsize=10)
plt.annotate(ExpOneDesc, (.04,.78), weight='regular', fontsize=9)
plt.annotate(ExpTwoTitle, (.02,.745), weight='bold', fontsize=10)
plt.annotate(ExpTwoDesc, (.04,.71), weight='regular', fontsize=9)
plt.annotate(ExpThreeTitle, (.02,.672), weight='bold', fontsize=10)
plt.annotate(ExpThreeDesc, (.04,.608), weight='regular', fontsize=9)
plt.annotate(EduHeader, (.02,.54), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.495), weight='bold', fontsize=10)
plt.annotate(EduOneTime, (.02,.475), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduTwoTitle, (.02,.42), weight='bold', fontsize=10)
plt.annotate(EduTwoTime, (.02,.398), weight='regular', fontsize=9, alpha=.6)
plt.annotate(EduThreeTitle, (.02,.343), weight='bold', fontsize=10)
plt.annotate(EduThreeTime, (.02,.32), weight='regular', fontsize=9, alpha=.6)
plt.annotate(CoursesHeader, (.02,.28), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(CourseOneTitle, (.02,.255), weight='bold', fontsize=10)
plt.annotate(CourseOneTime, (.02,.239), weight='regular', fontsize=9, alpha=.6)
plt.annotate(CourseTwoTitle, (.02,.210), weight='bold', fontsize=10)
plt.annotate(CourseTwoTime, (.02,.193), weight='regular', fontsize=9, alpha=.6)
plt.annotate(CourseThreeTitle, (.02,.150), weight='bold', fontsize=10)
plt.annotate(CourseThreeTime, (.02,.130), weight='regular', fontsize=9, alpha=.6)
plt.annotate(CourseThreeDesc, (.04,.105), weight='regular', fontsize=9)
plt.annotate(SkillsHeader, (.7,.73), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.50), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(LanguageTitle, (.7,.35), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(LanguageDesc, (.7,.26), weight='regular', fontsize=10, color='#ffffff')
plt.annotate(ProjectHeader, (.7,.185), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ProjectOneTitle, (.7,.145), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ProjectOneTime, (.7,.122), weight='regular', fontsize=10, alpha=.6, color='#ffffff')
# Out:
# Text(0.7, 0.122, 'Decembre 2017')
