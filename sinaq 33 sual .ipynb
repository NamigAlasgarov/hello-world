# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import numpy as np

# %% [markdown]
# ## Sual 1

# %%
data = {'apples':[30],
        'bananas':[21]}

df=pd.DataFrame(data)
df
# Out:
#    apples  bananas
# 0      30       21

# %%
data = {'':['2017 Sales', '2018 Sales'],
        'apples':[35,41],
        'bananas':[21,34]}

df=pd.DataFrame(data)
df
# Out:
#                apples  bananas
# 0  2017 Sales      35       21
# 1  2018 Sales      41       34

# %% [markdown]
# ## Sual 2

# %%
data =np.array(['4 cups', '1 cup', '2 large', '1 can'])

ser = pd.Series(data, index= ['Flour', 'Milk', 'Eggs', 'Spam'])

result = ser.rename('Dinner')

print(result)
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %% [markdown]
# ## Sual 3

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')

df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ## Sual 4

# %%
data = {'':['Year 1','year 2'],'Cows':[12,20],'Goats':[22,19]}
df = pd.DataFrame(data)
df
# Out:
#            Cows  Goats
# 0  Year 1    12     22
# 1  year 2    20     19

# %%
header = ['','Cows','Goats']
data = [['Year 1', 12, 22],['Year 2', 20, 19]]
data = pd.DataFrame(data, columns=header)
df
data.to_csv('animals.csv', index=False)

# %% [markdown]
# ## Sual 5

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
desc = df['description']
desc = pd.DataFrame(desc)
desc
# Out:
#                                               description
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 1 columns]

# %% [markdown]
# ## Sual 6

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
desc = pd.DataFrame(desc)
desc.head(1)
# Out:
#                                          description
# 0  Aromas include tropical fruit, broom, brimston...

# %% [markdown]
# ## Sual 7

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df.head(1)
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %% [markdown]
# ## Sual 8

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
series_one = pd.Series(df.description)
print(series_one.head(10))
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# 5    Blackberry and raspberry aromas show a typical...
# 6    Here's a bright, informal red that opens with ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, dtype: object

# %% [markdown]
# ## Sual 9

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
frame2 = df[['country', 'province','region_1','region_2']]
frame2.iloc[[0,1,10,100]]
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %% [markdown]
# ## sual 10

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
frame3 = df[['country','variety']]
frame3.head(100)
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# 2         US                Pinot Gris
# 3         US                  Riesling
# 4         US                Pinot Noir
# ..       ...                       ...
# 95    France                     Gamay
# 96    France                     Gamay
# 97        US                  Riesling
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %% [markdown]
# ## sual 11

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
frame3 = df[['country']]
frame3.iloc[0:15]
# Out:
#      country
# 0      Italy
# 1   Portugal
# 2         US
# 3         US
# 4         US
# 5      Spain
# 6      Italy
# 7     France
# 8    Germany
# 9     France
# 10        US
# 11    France
# 12        US
# 13     Italy
# 14        US

# %% [markdown]
# ## sual 12

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
frame4 = df[['variety']]
frame4.iloc[10:45]
# Out:
#                 variety
# 10   Cabernet Sauvignon
# 11       Gewürztraminer
# 12   Cabernet Sauvignon
# 13    Nerello Mascalese
# 14           Chardonnay
# 15             Riesling
# 16               Malbec
# 17               Malbec
# 18    Tempranillo Blend
# 19             Meritage
# 20            Red Blend
# 21           Pinot Noir
# 22          White Blend
# 23               Merlot
# 24         Nero d'Avola
# 25           Pinot Noir
# 26          White Blend
# 27         Nero d'Avola
# 28            Red Blend
# 29         Chenin Blanc
# 30                Gamay
# 31            Red Blend
# 32          White Blend
# 33            Red Blend
# 34      Sauvignon Blanc
# 35           Pinot Noir
# 36  Viognier-Chardonnay
# 37   Cabernet Sauvignon
# 38            Primitivo
# 39         Nero d'Avola
# 40           Catarratto
# 41           Pinot Noir
# 42                Gamay
# 43      Sauvignon Blanc
# 44               Merlot

# %% [markdown]
# ## sual 13

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df.set_index('country', inplace=True)
result = df.loc['Italy']
result
# Out:
#          Unnamed: 0                                        description  \
# country
# Italy             0  Aromas include tropical fruit, broom, brimston...
# Italy             6  Here's a bright, informal red that opens with ...
# Italy            13  This is dominated by oak and oak-driven aromas...
# Italy            22  Delicate aromas recall white flower and citrus...
# Italy            24  Aromas of prune, blackcurrant, toast and oak c...
# ...             ...                                                ...
# Italy        129929  This luminous sparkler has a sweet, fruit-forw...
# Italy        129943  A blend of Nero d'Avola and Syrah, this convey...
# Italy        129947  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# Italy        129961  Intense aromas of wild cherry, baking spice, t...
# Italy        129962  Blackberry, cassis, grilled herb and toasted a...
#
#                        designation  points  price           province  \
# country
# ...

# %% [markdown]
# ## sual 14

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
frame4 = df.iloc[:, 1:9]
frame4.iloc[10:46]
# Out:
#       country                                        description  \
# 10         US  Soft, supple plum envelopes an oaky structure ...
# 11     France  This is a dry wine, very spicy, with a tight, ...
# 12         US  Slightly reduced, this wine offers a chalky, t...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# 14         US  Building on 150 years and six generations of w...
# 15    Germany  Zesty orange peels and apple notes abound in t...
# 16  Argentina  Baked plum, molasses, balsamic vinegar and che...
# 17  Argentina  Raw black-cherry aromas are direct and simple ...
# 18      Spain  Desiccated blackberry, leather, charred wood a...
# 19         US  Red fruit aromas pervade on the nose, with cig...
# 20         US  Ripe aromas of dark berries mingle with ample ...
# 21         US  A sleek mix of tart berry, stem and herb, alon...
# 22      Italy  Delicate aromas recall white flower and citrus...
# ...

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df.loc[10:45, 'country':'region_2']
# Out:
#       country                                        description  \
# 10         US  Soft, supple plum envelopes an oaky structure ...
# 11     France  This is a dry wine, very spicy, with a tight, ...
# 12         US  Slightly reduced, this wine offers a chalky, t...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# 14         US  Building on 150 years and six generations of w...
# 15    Germany  Zesty orange peels and apple notes abound in t...
# 16  Argentina  Baked plum, molasses, balsamic vinegar and che...
# 17  Argentina  Raw black-cherry aromas are direct and simple ...
# 18      Spain  Desiccated blackberry, leather, charred wood a...
# 19         US  Red fruit aromas pervade on the nose, with cig...
# 20         US  Ripe aromas of dark berries mingle with ample ...
# 21         US  A sleek mix of tart berry, stem and herb, alon...
# 22      Italy  Delicate aromas recall white flower and citrus...
# ...

# %% [markdown]
# ## sual 15

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')

df1 = df.loc[((df['points']>95) & (df['country']=='Australia') | (df['country']=='New Zealand')),['country','winery','points']]
df1
# Out:
#             country                       winery  points
# 174     New Zealand                   Stoneleigh      88
# 311     New Zealand        Otto's Constant Dream      87
# 345       Australia  Chambers Rosewood Vineyards     100
# 346       Australia  Chambers Rosewood Vineyards      98
# 348       Australia  Chambers Rosewood Vineyards      97
# ...             ...                          ...     ...
# 129953  New Zealand                   Mills Reef      90
# 129954  New Zealand                          Ara      90
# 129955  New Zealand                    Dog Point      90
# 129956  New Zealand                   Esk Valley      90
# 129958  New Zealand                       Babich      90
#
# [1441 rows x 3 columns]

# %% [markdown]
# ## sual 16 baxx

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df.loc[[1,2,3,5,8]]
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 8           8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
# ...

# %% [markdown]
# ## sual 17

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df['points'].mean()
# Out:
# 88.44713820775404

# %%
median = df['points'].median()
median
# Out:
# 88.0

# %%
df['points'].max()
# Out:
# 100

# %%
df['points'].min()
# Out:
# 80

# %% [markdown]
# ## sual 18

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
df2=df.country.unique()
df2= pd.DataFrame(df2)
df2.sort_values(by = 0, ascending = True)
# Out:
#                          0
# 6                Argentina
# 36                 Armenia
# 8                Australia
# 9                  Austria
# 38  Bosnia and Herzegovina
# 29                  Brazil
# 34                Bulgaria
# 17                  Canada
# 7                    Chile
# 42                   China
# 23                 Croatia
# 35                  Cyprus
# 20          Czech Republic
# 43                   Egypt
# 26                 England
# 4                   France
# 24                 Georgia
# 5                  Germany
# 14                  Greece
# 13                 Hungary
# 33                   India
# 12                  Israel
# 0                    Italy
# 27                 Lebanon
# 22              Luxembourg
# 41               Macedonia
# 16                  Mexico
# 30                 Moldova
# 31                 Morocco
# 11             New Zealand
# 32                    Peru
# 1                 Portugal
# 15                 Romania
# ...

# %% [markdown]
# ## sual 19

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
olke_saylari = df['country'].value_counts()
olke_saylari
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# ## sual 20

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
mean = df['price'].mean()
mean
# Out:
# 35.363389129985535

# %%
df.price.sub(mean)
# Out:
# 0               NaN
# 1        -20.363389
# 2        -21.363389
# 3        -22.363389
# 4         29.636611
#             ...
# 129966    -7.363389
# 129967    39.636611
# 129968    -5.363389
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# ## sual 21 baxx

# %%
df.points.sub(df.price).max()
# Out:
# 84.0

# %%
maxim = df.points.sub(df.price).max()
maxim
df2 = df.loc[(maxim),['country','price','points','description']]
df2 = pd.DataFrame(df2)
df2
# Out:
#                                                             84
# country                                                     US
# price                                                     24.0
# points                                                      86
# description  A healthy addition of 13% Petite Sirah provide...

# %%
df['points-price'] = df['points']-df['price']
maks = df['points-price'].max()
ds = df[df['points-price']==maks]['country']
ds = pd.DataFrame(ds)
ds
# Out:
#         country
# 34629  Portugal

# %% [markdown]
# ## sual 22

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
sozler = df[df['description'].str.contains('tropical') | df['description'].str.contains('fruity') ]

len(sozler)
# Out:
# 12487

# %% [markdown]
# ## sual 23

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
conditions = [
    (df['country'] == 'Canada'),
    (df['points'] >= 95),
    (df['points'] <= 95) & (df['points'] >= 85)]
choices = [3, 3, 2]
df['rating'] = np.select(conditions, choices, default=1)
df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ## Sual 24

# %%
df = pd.read_csv(r'C:\Users\Namiq\Desktop\İNNAB\Python\winemag-data-130k-v2.csv')
say = df['taster_twitter_handle'].value_counts()
say
# Out:
# @vossroger          25514
# @wineschach         15134
# @kerinokeefe        10776
# @vboone              9537
# @paulgwine           9532
# @mattkettmann        6332
# @JoeCz               5147
# @wawinereport        4966
# @gordone_cellars     4177
# @AnneInVino          3685
# @laurbuzz            1835
# @suskostrzewa        1085
# @worldwineguys       1005
# @bkfiona               27
# @winewchristina         6
# Name: taster_twitter_handle, dtype: int64

# %% [markdown]
# ## sual 25

# %%
df.groupby('price')[['points']].agg({'points':'max'})
# Out:
#         points
# price
# 4.0         86
# 5.0         87
# 6.0         88
# 7.0         91
# 8.0         91
# ...        ...
# 1900.0      98
# 2000.0      97
# 2013.0      91
# 2500.0      96
# 3300.0      88
#
# [390 rows x 1 columns]

# %% [markdown]
# ## Sual 26

# %%
df.groupby('variety')[['price']].agg({'price':['max','min']})
# Out:
#              price
#                max   min
# variety
# Abouriou      75.0  15.0
# Agiorgitiko   66.0  10.0
# Aglianico    180.0   6.0
# Aidani        27.0  27.0
# Airen         10.0   8.0
# ...            ...   ...
# Zinfandel    100.0   5.0
# Zlahtina      16.0  13.0
# Zweigelt      70.0   9.0
# Çalkarası     19.0  19.0
# Žilavka       15.0  15.0
#
# [707 rows x 2 columns]

# %% [markdown]
# ## sual 27

# %%
df.groupby('taster_name')[['points']].agg({'points':['mean','median','max','min']})
# Out:
#                        points
#                          mean median  max min
# taster_name
# Alexander Peartree  85.855422   86.0   91  80
# Anna Lee C. Iijima  88.415629   88.0   98  80
# Anne Krebiehl MW    90.562551   90.0   97  80
# Carrie Dykes        86.395683   87.0   92  81
# Christina Pickard   87.833333   88.0   93  82
# Fiona Adams         86.888889   87.0   91  82
# Jeff Jenssen        88.319756   89.0   97  82
# Jim Gordon          88.626287   89.0   97  80
# Joe Czerwinski      88.536235   89.0  100  80
# Kerin O’Keefe       88.867947   89.0  100  80
# Lauren Buzzeo       87.739510   88.0   95  81
# Matt Kettmann       90.008686   90.0   97  81
# Michael Schachner   86.907493   87.0   98  80
# Mike DeSimone       89.101167   89.0   94  82
# Paul Gregutt        89.082564   89.0  100  80
# Roger Voss          88.708003   88.0  100  80
# Sean P. Sullivan    88.755739   89.0   97  80
# Susan Kostrzewa     86.609217   87.0   94  80
# ...

# %% [markdown]
# ## sual 28

# %%
df.groupby(['country','variety']).size().reset_index().rename(columns={0:'sayi'}).sort_values(['sayi'], ascending=False).head(20)
# Out:
#         country                   variety  sayi
# 1489         US                Pinot Noir  9885
# 1358         US        Cabernet Sauvignon  7315
# 1380         US                Chardonnay  6801
# 371      France  Bordeaux-style Red Blend  4725
# 814       Italy                 Red Blend  3624
# 1536         US                     Syrah  3244
# 1497         US                 Red Blend  2972
# 388      France                Chardonnay  2808
# 782       Italy                  Nebbiolo  2736
# 1586         US                 Zinfandel  2711
# 1028   Portugal            Portuguese Red  2466
# 1441         US                    Merlot  2311
# 824       Italy                Sangiovese  2265
# 1519         US           Sauvignon Blanc  2163
# 463      France                Pinot Noir  1966
# 475      France                      Rosé  1923
# 1348         US  Bordeaux-style Red Blend  1824
# 544     Germany                  Riesling  1790
# 1502         US                  Riesling  1753
# ...

# %% [markdown]
# ## sual 29

# %%
df.dtypes['points']
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %% [markdown]
# ## sual 30

# %%
df = df.astype({"points": str}, errors = 'raise') 
df.dtypes
df3 = pd.DataFrame(df.dtypes)
df3
# Out:
# Unnamed: 0                 int64
# country                   object
# description               object
# designation               object
# points                    object
# price                    float64
# province                  object
# region                    object
# locale                    object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %% [markdown]
# ## sual 31

# %%
dict = {'region_1': 'region', 'region_2': 'locale'}

df.rename(columns = dict, inplace = True)

df
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ## sual 32

# %%
df.index.name = 'wines'
df
# Out:
#         Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %% [markdown]
# ## sual 33

# %%
data = {'a':[0,5,10,15],
        'b':[1,6,11,16],
        'c':[2,7,12,17],
        'd':[3,8,13,18],
        'e':[4,9,14,19]}

df11=pd.DataFrame(data)
df11
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
l = [{'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4},
     {'a': 5, 'b': 6, 'c': 7, 'd': 8, 'e': 9},
     {'a': 10, 'b': 11, 'c': 12, 'd': 13, 'e': 14},
     {'a': 15, 'b': 16, 'c': 17, 'd': 18, 'e': 19}]

pd.DataFrame(l)
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19
